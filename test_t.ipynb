# %%
from utils.data import *
from matplotlib import pyplot as plt

# %%
source = sourceDiagonalMatching()
target = targetDiagonalMatching()

# %%
source(100).T.shape
# Out:
# torch.Size([2, 100])

# %%
source_points = source(100)
target_points = target(100)

plt.scatter(*source(100).T)
plt.scatter(*target(100).T)
# 按照索引连接点
for s, t in zip(source_points, target_points):
    plt.plot([s[0], t[0]], [s[1], t[1]], 'r--', linewidth=0.5)

plt.show()

# %%
source_points.shape
# Out:
# torch.Size([100, 2])
