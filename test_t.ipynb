# %%
from utils.data import *
from matplotlib import pyplot as plt
from sklearn.datasets import make_s_curve, make_moons

# %%
source(1000).shape
# Out:
# torch.Size([1000, 2])

# %%
# set figure size
source = sourceMoon()
target = targetMoon()
src = source(100)
trt = target(100)
plt.rcParams['figure.figsize'] = [10, 10]
plt.xlim(-10, 10)
plt.ylim(-10, 10)
plt.scatter(*src.T)
plt.scatter(*trt.T)
for i in range(100):
    plt.plot([src[i][0], trt[i][0]], [src[i][1], trt[i][1]], 'k-', lw=0.1)
